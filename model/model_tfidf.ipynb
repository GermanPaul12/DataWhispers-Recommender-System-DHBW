# %%
import pandas as pd
import numpy as np
import os
import nltk
import string
import ast
import pickle
from collections import Counter
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /home/german/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Read the CSV files
history_df = pd.read_csv('../data/netflix_history_preprocessed.csv')
titles_df = pd.read_csv('../data/all_plattforms_titles_preprocessed.csv')

# %%
history_df
# Out:
#                         Title           Start Time  Total Duration
# 0    tote mädchen lügen nicht  2018-06-04 17:39:00        154323.0
# 1             haus des geldes  2018-06-17 13:45:00        196086.0
# 2                      naruto  2018-06-28 06:09:00        280744.0
# 3                  death note  2018-06-28 10:51:00          5999.0
# 4             stranger things  2018-06-29 08:39:00         25353.0
# ..                        ...                  ...             ...
# 270     tiny house nation usa  2022-12-15 17:29:00         33778.0
# 271     falling for christmas  2022-12-24 20:52:00          5555.0
# 272        your place or mine  2023-02-13 20:54:00          6257.0
# 273   anatomie eines skandals  2023-03-05 20:45:00         14850.0
# 274           the night agent  2023-03-29 10:40:00          4555.0
#
# [275 rows x 3 columns]

# %%
# Convert string representation of list to actual list
titles_df['director'] = titles_df['director'].apply(ast.literal_eval)
titles_df['cast'] = titles_df['cast'].apply(ast.literal_eval)
titles_df['country'] = titles_df['country'].apply(ast.literal_eval)
titles_df['listed_in'] = titles_df['listed_in'].apply(ast.literal_eval)

# %%
# Keep only the first occurrence of each title
titles_df = titles_df.drop_duplicates(subset=['title'], keep='first').reset_index(drop=True)

# %%
titles_df
# Out:
#                                        title                     director  \
# 0                       dick johnson is dead            [kirsten johnson]
# 1                              blood & water                           []
# 2                                  ganglands            [julien leclercq]
# 3                      jailbirds new orleans                           []
# 4                               kota factory                           []
# ...                                      ...                          ...
# 18113                           tomorrowland                  [brad bird]
# 18114                             aquamarine  [elizabeth allen rosenbaum]
# 18115                        eddie the eagle            [dexter fletcher]
# 18116                   bend it like beckham            [gurinder chadha]
# 18117  captain sparky vs. the flying saucers                [mark waring]
#
#                                                     cast  \
# 0                                                     []
# 1      [ama qamata,  khosi ngema,  gail mabalane,  th...
# 2      [sami bouajila,  tracy gotoas,  samuel jouy,  ...
# 3                                                     []
# 4      [mayur more,  jitendra kumar,  ranjan raj,  al...
# ...                                                  ...
# 18113  [george clooney,  hugh laurie,  britt robertso...
# 18114  [jake mcdorman,  arielle kebbel,  claudia karv...
# 18115  [tom costello,  jo hartley,  keith allen,  dic...
# 18116  [parminder nagra,  keira knightley,  jonathan ...
# 18117                                    [charlie tahan]
#
#                                                  country          date_added  \
# 0                                        [united states]  september 25, 2021
# 1                                         [south africa]  september 24, 2021
# 2                                                     []  september 24, 2021
# 3                                                     []  september 24, 2021
# 4                                                [india]  september 24, 2021
# ...                                                  ...                 ...
# 18113  [united states,  spain,  france,  canada,  uni...   september 3, 2021
# 18114                                    [united states]     august 13, 2021
# 18115         [united kingdom,  germany,  united states]   december 18, 2020
# 18116         [united kingdom,  germany,  united states]  september 18, 2020
# 18117                                    [united states]       april 1, 2020
#
#        release_year                                          listed_in  \
# 0              2020                                    [documentaries]
# 1              2021  [international tv shows,  tv dramas,  tv myste...
# 2              2021  [crime tv shows,  international tv shows,  tv ...
# 3              2021                          [docuseries,  reality tv]
# 4              2021  [international tv shows,  romantic tv shows,  ...
# ...             ...                                                ...
# 18113          2015               [action-adventure,  science fiction]
# 18114          2006                 [comedy,  coming of age,  fantasy]
# 18115          2016                    [biographical,  comedy,  drama]
# 18116          2003                   [buddy,  comedy,  coming of age]
# 18117          2012  [action-adventure,  animals & nature,  animation]
#
#                                              description     platform
# 0      as her father nears the end of his life, filmm...      netflix
# 1      after crossing paths at a party, a cape town t...      netflix
# 2      to protect his family from a powerful drug lor...      netflix
# 3      feuds, flirtations and toilet talk go down amo...      netflix
# 4      in a city of coaching centers known to train i...      netflix
# ...                                                  ...          ...
# 18113  a jaded genius and an optimistic teen unearth ...  disney_plus
# 18114  two 13-year-old best friends embark on an adve...  disney_plus
# 18115  true story of eddie edwards, a british ski-jum...  disney_plus
# 18116  despite the wishes of their traditional famili...  disney_plus
# 18117         view one of sparky's favorite home movies.  disney_plus
#
# [18118 rows x 9 columns]

# %%
history_titles_set = set(history_df['Title'])
titles_set = set(titles_df['title'])

# %%
overlaps = history_titles_set.intersection(titles_set)

# %%
en_history_df = history_df[history_df['Title'].isin(overlaps)]

# %%
en_history_df
# Out:
#                      Title           Start Time  Total Duration
# 2                   naruto  2018-06-28 06:09:00        280744.0
# 3               death note  2018-06-28 10:51:00          5999.0
# 4          stranger things  2018-06-29 08:39:00         25353.0
# 6               cowspiracy  2018-07-01 19:08:00         10585.0
# 8           house of cards  2018-07-20 15:19:00        126137.0
# ..                     ...                  ...             ...
# 250     a christmas prince  2021-12-24 14:50:00         15556.0
# 252       the last kingdom  2022-01-03 08:03:00        136762.0
# 253      the game changers  2022-02-01 11:58:00          4887.0
# 255             seaspiracy  2022-02-22 15:22:00          3177.0
# 271  falling for christmas  2022-12-24 20:52:00          5555.0
#
# [120 rows x 3 columns]

# %%
watch_history = en_history_df['Title'].to_list()
watch_history
# Out:
# ['naruto',
#  'death note',
#  'stranger things',
#  'cowspiracy',
#  'house of cards',
#  'welcome to the family',
#  'titanic',
#  'riverdale',
#  'gossip girl',
#  'orange is the new black',
#  'sierra burgess is a loser',
#  'to all the boys i’ve loved before',
#  'the kissing booth',
#  'greenhouse academy',
#  'insatiable',
#  '#realityhigh',
#  'dude',
#  'you get me',
#  'shooter',
#  'american horror story',
#  'chilling adventures of sabrina',
#  'black butler',
#  'baby',
#  'sex education',
#  'bodyguard',
#  'suits',
#  'how to get away with murder',
#  'the order',
#  'on my block',
#  'the perfect date',
#  'the protector',
#  'bonding',
#  'the last summer',
#  'kidnapping stella',
#  'sintonia',
#  'the seven deadly sins',
#  'the irregular at magic high school',
#  'cam',
#  'naruto shippuden',
#  'castlevania',
#  'how to sell drugs online (fast)',
#  'the end of the f***ing world',
#  'baki',
#  'grimoire of zero',
#  'the irishman',
#  'revisions',
#  'hot girls wanted',
#  'the witcher',
#  'mulan',
#  'the blacklist',
#  'flavors of youth',
#  'attack on titan',
#  'big mouth',
#  'granblue fantasy the animation',
#  'tiger king',
#  'kengan ashura',
#  'beyblade burst',
#  'ghost in the shell',
#  'how i met your mother',
#  'vikings',
#  'too hot to handle',
#  'insidious',
#  'nymphomaniac',
#  'hostel',
#  'no game no life',
#  'chappie',
#  '365 days',
#  'the app',
#  'the bye bye man',
#  'sword art online',
#  'the kissing booth 2',
#  'fate/zero',
#  'newness',
#  "dragon's dogma",
#  'enola holmes',
#  'the it crowd',
#  'rebecca',
#  'pokémon',
#  'erased',
#  'holidate',
#  'isi & ossi',
#  'midnight at the magnolia',
#  'catch me if you can',
#  'christmas wedding planner',
#  'the holiday calendar',
#  'a california christmas',
#  'the christmas chronicles',
#  'bridgerton',
#  'lupin',
#  'to all the boys',
#  'ginny & georgia',
#  'devilman crybaby',
#  'yes day',
#  'dota',
#  'fate/grand order',
#  'fate/apocrypha',
#  'fate/stay night',
#  'fate/extra last encore',
#  'neon genesis evangelion',
#  'last hope',
#  'the end of evangelion',
#  'evangelion',
#  'charité',
#  'the impossible',
#  'record of ragnarok',
#  'mortal kombat',
#  'resident evil',
#  'record of grancrest war',
#  'rascal does not dream of bunny girl senpai',
#  'shaman king',
#  'overlord',
#  'silver skates',
#  'the kissing booth 3',
#  'squid game',
#  'darwin’s game',
#  'a christmas prince',
#  'the last kingdom',
#  'the game changers',
#  'seaspiracy',
#  'falling for christmas']

# %%
def preprocess_text(text):
    # Tokenization
    tokens = nltk.tokenize.word_tokenize(text.lower())

    # Remove punctuation
    tokens = [token for token in tokens if token not in string.punctuation]

    # Remove stop words
    stop_words = set(nltk.corpus.stopwords.words('english'))
    tokens = [token for token in tokens if token not in stop_words]

    # Stemming
    stemmer = nltk.stem.PorterStemmer()
    tokens = [stemmer.stem(token) for token in tokens]

    return ' '.join(tokens)

# %%
titles_df['description'] = titles_df['description'].apply(preprocess_text)

# %%
def preprocess_name(name_list):
    # Remove spaces between each name
    return [name.replace(' ', '') for name in name_list]

# %%
titles_df['director'] = titles_df['director'].apply(preprocess_name)
titles_df['cast'] = titles_df['cast'].apply(preprocess_name)

# %%
# Flatten the list of actor names
actor_names = [name for sublist in titles_df['cast'] for name in sublist]

# Count the occurrences of each actor name
name_counts = Counter(actor_names)

# %%
def keep_top_three_actors(actor_list):
    if len(actor_list) == 0:
        return []
    # Keep only the top k most frequent actors
    actor_list.sort(key=lambda x: name_counts[x], reverse=True)
    return actor_list[:3]

# %%
titles_df['cast'] = titles_df['cast'].apply(keep_top_three_actors)

# %%
titles_df
# Out:
#                                        title                   director  \
# 0                       dick johnson is dead           [kirstenjohnson]
# 1                              blood & water                         []
# 2                                  ganglands           [julienleclercq]
# 3                      jailbirds new orleans                         []
# 4                               kota factory                         []
# ...                                      ...                        ...
# 18113                           tomorrowland                 [bradbird]
# 18114                             aquamarine  [elizabethallenrosenbaum]
# 18115                        eddie the eagle           [dexterfletcher]
# 18116                   bend it like beckham           [gurinderchadha]
# 18117  captain sparky vs. the flying saucers               [markwaring]
#
#                                                   cast  \
# 0                                                   []
# 1      [thabangmolaba, cindymahlangu, patrickmofokeng]
# 2            [samibouajila, samueljouy, sofialesaffre]
# 3                                                   []
# 4             [jitendrakumar, mayurmore, ahsaaschanna]
# ...                                                ...
# 18113         [kathrynhahn, georgeclooney, hughlaurie]
# 18114      [ariellekebbel, brucespence, claudiakarvan]
# 18115            [taronegerton, johartley, keithallen]
# 18116     [anupamkher, keiraknightley, parmindernagra]
# 18117                                   [charlietahan]
#
#                                                  country          date_added  \
# 0                                        [united states]  september 25, 2021
# 1                                         [south africa]  september 24, 2021
# 2                                                     []  september 24, 2021
# 3                                                     []  september 24, 2021
# 4                                                [india]  september 24, 2021
# ...                                                  ...                 ...
# 18113  [united states,  spain,  france,  canada,  uni...   september 3, 2021
# 18114                                    [united states]     august 13, 2021
# 18115         [united kingdom,  germany,  united states]   december 18, 2020
# 18116         [united kingdom,  germany,  united states]  september 18, 2020
# 18117                                    [united states]       april 1, 2020
#
#        release_year                                          listed_in  \
# 0              2020                                    [documentaries]
# 1              2021  [international tv shows,  tv dramas,  tv myste...
# 2              2021  [crime tv shows,  international tv shows,  tv ...
# 3              2021                          [docuseries,  reality tv]
# 4              2021  [international tv shows,  romantic tv shows,  ...
# ...             ...                                                ...
# 18113          2015               [action-adventure,  science fiction]
# 18114          2006                 [comedy,  coming of age,  fantasy]
# 18115          2016                    [biographical,  comedy,  drama]
# 18116          2003                   [buddy,  comedy,  coming of age]
# 18117          2012  [action-adventure,  animals & nature,  animation]
#
#                                              description     platform
# 0      father near end life filmmak kirsten johnson s...      netflix
# 1      cross path parti cape town teen set prove whet...      netflix
# 2      protect famili power drug lord skill thief meh...      netflix
# 3      feud flirtat toilet talk go among incarcer wom...      netflix
# 4      citi coach center known train india ’ finest c...      netflix
# ...                                                  ...          ...
# 18113  jade geniu optimist teen unearth secret tomorr...  disney_plus
# 18114  two 13-year-old best friend embark adventur di...  disney_plus
# 18115  true stori eddi edward british ski-jump whose ...  disney_plus
# 18116  despit wish tradit famili two girl aim career ...  disney_plus
# 18117               view one sparki 's favorit home movi  disney_plus
#
# [18118 rows x 9 columns]

# %%
# Calculate TF-IDF vectors for processed titles and descriptions
tfidf_vectorizer = TfidfVectorizer()
titles_tfidf = tfidf_vectorizer.fit_transform(titles_df['description'])

# Calculate cosine similarity
similarity_scores = cosine_similarity(titles_tfidf, titles_tfidf)

# %%
# Function to check if two lists have overlapping elements
def have_overlap(list1, list2):
    return bool(set(list1) & set(list2))

def create_overlap_matrix(column_name):
    matrix_size = len(titles_df)
    overlap_matrix = np.zeros((matrix_size, matrix_size), dtype=int)

    column = titles_df[column_name].to_list()
    for i in range(matrix_size):
        for j in range(matrix_size):
            if have_overlap(column[i], column[j]):
                overlap_matrix[i, j] = 1

    return overlap_matrix

# %%
overlap_director = create_overlap_matrix('director')
overlap_cast = create_overlap_matrix('cast')
overlap_country = create_overlap_matrix('country')
overlap_genre = create_overlap_matrix('listed_in')

# %%
# Evaluation of the recommendation
def evaluate(x1, x2, x3, x4, x5, consider_history=False):
    target_ranks = []
    combined_scores = x1 * similarity_scores + x2 * overlap_director + x3 * overlap_cast + x4 * overlap_country + x5 * overlap_genre
    scores = np.zeros(combined_scores.shape[0])

    for i in range(1, len(watch_history)):
        target_title = watch_history[i]
        target_row_index = titles_df.index[titles_df['title'] == target_title].tolist()[0]
        prev_title = watch_history[i - 1]
        prev_row_index = titles_df.index[titles_df['title'] == prev_title].tolist()[0]

        # Get recommendation based on the similarity
        if consider_history:
            scores += combined_scores[prev_row_index]
        else:
            scores = combined_scores[prev_row_index]
        recommendation_indices = sorted(range(len(scores)), key=lambda i: scores[i], reverse=True)
        target_rank = recommendation_indices.index(target_row_index)
        target_ranks.append(target_rank)

    print('Average rank:', np.mean(target_ranks))
    print('Successful recommendations:', np.sum(np.array(target_ranks) <= 5))

# %%
evaluate(1, 0, 0, 0, 0)
# Out:
# Average rank: 4661.890756302521
# Successful recommendations: 3

# %%
evaluate(1, 0, 0, 0, 0, True)
# Out:
# Average rank: 6336.285714285715
# Successful recommendations: 0

# %%
evaluate(0, 1, 2, 0.5, 2)
# Out:
# Average rank: 2491.3303571428573
# Successful recommendations: 2

# %%
evaluate(0, 1, 2, 0.5, 2, True)
# Out:
# Average rank: 2440.5535714285716
# Successful recommendations: 1

# %%
evaluate(50, 1, 2, 0.5, 2)
# Out:
# Average rank: 2638.8928571428573
# Successful recommendations: 3

# %%
evaluate(50, 1, 2, 0.5, 2, True)
# Out:
# Average rank: 2307.4910714285716
# Successful recommendations: 0

# %%
combined_scores = 50 * similarity_scores + 1 * overlap_director + 2 * overlap_cast + 0.5 * overlap_country + 2 * overlap_genre
combined_scores = np.array(combined_scores, dtype=np.float32)

pickle.dump(combined_scores, open('../data/similarity_tfidf.pkl', 'wb'))
